    "staffordshire":[1754570,1753132,1753251,1754143,1753433,1753645,1751636,1753018,1752722,1753377],
    "suffolk":[1617693,1615899,1616366,1615829,1615516,1615088,1618668,1618651,1618353,1618004],
    "surrey":[2000872,2000859,2000846,2002334,2002475,2001678,2000688,2000727,2000858,2001254],
    "sussex":[2191037,2186376,2188020,2188358,2189042,2190032,2190602,2191021,2192079,2193192],
    "thames-valley":[1957657,1964670,1964362,1964007,1966380,1957337,1956856,1954944,1967879,1967965],
    "warwickshire":[1530754,1527416,1530612,1530597,1529730,1532536,1532844,1532846,1534782,1534631],
    "west-mercia":[1844671,1844526,1844115,1843486,1840938,1839056,1834042,1841552,1832417,1838363],
    "west-midlands":[1638976,1625214,1627751,1632286,1642945,1639174,1632742,1639336,1635764,1643567],
    "west-yorkshire":[1286411,2121423,2120303,2127516,2109720,2106000,2110153,2107349,2106564,2106080],
    "wiltshire":[1826124,1825271,1826563,1828479,1819332,1818902,1820003,1825933,1822484,1822019]
}  
def Suc_Durumlari(kategori = "all-crime"):
    from collections import Counter
    import pandas as pd
    import requests
    import folium
    #GÜCLER DATAFRAME
    forces = "https://data.police.uk/api/forces"
    response = requests.get(forces)
    df = pd.DataFrame(response.json())
    #-------------------------------------------------------------------------------
    
    #ŞEHİR İSİMLERİNİN DATAFRAME'İNE ULAŞMAK
    if input("Arama yapmak istediğin polis güçlerini görmek ister misin | Evet, Hayır: ") == "Evet":
        liste = []
        for _,row in df.iterrows():
            print("{}. Şehir:\t {}".format(_,row["id"]))
    else:
        None
    #-------------------------------------------------------------------------------
    
    sehir = input("Aramak istediğiniz polis güçünü hatasız bir şekilde yazınız: ")
    zaman = input("Aramak istediğiniz zaman aralığını yazınız | Ör: 2023-05: ")
    
    
    
    #MAP OLUSTURMA
    suclar = []
    latitude = 52.3555
    longitude = -1.1743
    m = folium.Map(location=[latitude, longitude], zoom_start=6)
    #-------------------------------------------------------------------------------
    
    
    #MARKER İCİN KONUM ALMAK
    custom_icon = folium.Icon(icon='cloud', color='purple')
    konumlar = []
    for _,row in df.iterrows():
        if sehir == row["id"]:
            for location in location_idler.items():
                if sehir == location[0]:
                    for lokasyon in location[1]:
                        main_url = "https://data.police.uk/api/crimes-at-location"
                        payload = {
                            "date":zaman,
                            "location_id":lokasyon
                        }
                        response = requests.get(main_url,params=payload)
                        df_all = pd.DataFrame(response.json())
                        if response.status_code == 200:
                            if response.json() == []:
                                pass
                            else:
                                
                                
                                for index,kolon in df_all.iterrows():
                                    dictionaries = [kolon["location"]["latitude"], kolon["location"]["longitude"]]
                                    for _,row in df_all.iterrows():
                                        suclar.append(row["category"])
                                        most = ("Aradığınız yerde en fazla işlenen suç: <b>{}</b>,işlenen suçun miktarı: <b>{}</b>".
                                                format(
                                        Counter(suclar).most_common()[0][0],
                                        Counter(suclar).most_common()[0][1])) 
                                    folium.Marker(location=
                                                  dictionaries,
                                                  popup=folium.Popup(most, max_width=500),
                                                  icon=folium.Icon(icon="glyphicon-exclamation-sign", color="red")
                                                 ).add_to(m)
                                    suclar = []
                                    break
                        else:
                            pass
    return(m)
    #-------------------------------------------------------------------------------

# %%
Suc_Durumlari()
